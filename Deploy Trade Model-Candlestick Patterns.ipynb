# %%
import numpy as np
import time
import datetime as dt
import yfinance as yf
from ib_insync import *
import pandas as pd
import sys
import sched
import datetime
import pandas_ta as ta
import warnings

##### Warnings for invalid values/dividing by zero
warnings.filterwarnings("ignore")

def exit():
    print('{} Now the system will exit '.format(datetime.datetime.now()))
    sys.exit()

class CaptureReturn:
    def __init__(self, func, initial_state):
        self.func = func
        self.state = initial_state

    def call_func(self):
        self.output = self.func(self.state)
        return self.output

def get_stock_info(stock): 
    attempts = 3 
    for attempt in range(1, attempts+1): 
        
        data = yf.download(tickers=stock, period = '2d', interval='2m').round(decimals=3)
        if data.empty:
            print(f'Attempt {attempt} Failed, Dataset Empty.')
            time.sleep(3)
            continue
        else:
            print(f'Downloaded in Attempt {attempt}')
            break      
    return data

def place_order(direction, stock, amount): 
    order = MarketOrder(direction, amount)
    contract = Stock(stock, 'SMART', 'USD')
    trade = ib.placeOrder(contract, order)         
    return trade

def order_status(trade): ################
    if trade.orderStatus.status == 'Filled': ################
        fill = trade.fills[-1] ################
        price = fill.execution.avgPrice ################
        print(f'{fill.time} - {fill.execution.avgPrice}')
        return price ################

def trade_algo(data, buy_signals, sell_signals, buy_price, trigger, stock, amount): ################

    def ema(dataset, price, interval):
        ema_column = ta.ema(dataset[price], length=interval)
        data_ema = dataset.assign(ema=ema_column)
        return data_ema
    
    def atr(dataset, high, low, close, interval):
        average_tr = ta.atr(dataset[high], dataset[low], dataset[close])
        data_atr = dataset.assign(atr = average_tr)
        return data_atr
    
    df_ema_12 = ema(data, 'Close', 12).round(decimals=3)
    df_ema_50 = ema(data, 'Close', 50).round(decimals=3)
    df_atr = atr(data, 'High', 'Low', 'Close', 14).round(decimals=3)
    
    high = data["High"]
    open = data["Open"]
    close = data["Close"]
    low = data["Low"]
    atr = df_atr["atr"]
    ema_12 = df_ema_12["ema"]
    ema_50 = df_ema_50["ema"]
    
    body_candle_1 = close[-3] - open[-3]
    body_candle = close[-2] - open[-2]

    high_stick_hammer = abs(high[-2] - close[-2])
    low_stick_hammer = abs(open[-2] - low[-2])

    high_stick_int = abs(high[-2] - open[-2])
    low_stick_int = abs(close[-2] - low[-2])
                
    ##### Hammer Candlestick patterns    
        
    if low_stick_hammer/abs(body_candle) > 3 and body_candle > 0 \
    and high_stick_hammer/low_stick_hammer < 0.25 and ema_12[-2] > ema_50[-2] and trigger != 1:

        trade = place_order('BUY', stock, amount)
        buy_price = close[-2]
        print("bought at ", close[-2], "at ", data.index[-2], 'time now: ',
                  datetime.datetime.now().strftime("%H:%M:%S"), 'with hammer pattern')
        print("open: ", open[-2], "high: ", high[-2], "low: ", low[-2], "low stick/body: ", 
              low_stick_hammer/abs(body_candle), "high stick/low stick", high_stick_hammer/low_stick_hammer)
        time.sleep(3) 
        buy_signals.append(close[-2])
        trigger = 1
    
    ##### Int Hammer Candlestick patterns    

    elif low_stick_int/abs(body_candle) > 3 and body_candle < 0 \
    and high_stick_int/low_stick_int < 0.25 and ema_12[-2] > ema_50[-2] and trigger != 1:

        trade = place_order('BUY', stock, amount)
        buy_price = close[-2]
        print("bought at ", close[-2], "at ", data.index[-2], 'time now: ',
                  datetime.datetime.now().strftime("%H:%M:%S"), 'with int hammer pattern')
        print("open: ", open[-2], "high: ", high[-2], "low: ", low[-2], "low stick/body: ", 
              low_stick_int/abs(body_candle), "high stick/low stick", high_stick_int/low_stick_int)

        time.sleep(3) 
        buy_signals.append(close[-2])
        trigger = 1
        
    ##### Bullish/Bearing Engulfing patterns
        
    elif open[-2] <= close[-3] and close[-2] >= open[-3]\
    and abs(body_candle)/abs(body_candle_1) > 4 and body_candle_1 < 0 and body_candle > 0 \
    and close[-2]/open[-2] > 1.03 and ema_12[-2] > ema_50[-2] and trigger != 1:
        
        trade = place_order('BUY', stock, amount)
        buy_price = close[-2]
        print("bought at ", close[-2], "at ", data.index[-2], 'time now: ', 
                  datetime.datetime.now().strftime("%H:%M:%S"), 'with engulfing pattern')
        print("open: ", open[-2], "high: ", high[-2], "low: ", low[-2], "body ratios: ", 
              abs(body_candle)/abs(body_candle_1))

        time.sleep(3) 
        buy_signals.append(close[-2])
        trigger = 1
        
    ########## ATR sell off
    
    elif close[-2] > buy_price + 3*atr[-2] and trigger != -1 \
    or close[-2] < buy_price - 3*atr[-2] and trigger != -1:
        
        if trigger == 0:
            print("closing price: ", close[-2], "closing time: ", data.index[-2], "time now ", 
                  datetime.datetime.now().strftime("%H:%M:%S"))
            print("open: ", open[-2], "high: ", high[-2], "low: ", low[-2], "time now: ",
                  datetime.datetime.now().strftime("%H:%M:%S"))
        
        else:
            trade = place_order('SELL', stock, amount)
            print("sold at: ", close[-2], "closing time: ", data.index[-2], "time now ", 
                  datetime.datetime.now().strftime("%H:%M:%S"))
            
            time.sleep(3)
            sell_signals.append(close[-2])
            trigger = -1
            
    else:
        print("closing price: ", close[-2], "closing time: ", data.index[-2], "time now ", 
              datetime.datetime.now().strftime("%H:%M:%S"))
        print("open: ", open[-2], "high: ", high[-2], "low: ", low[-2], "time now: ",
                  datetime.datetime.now().strftime("%H:%M:%S"))
        
    return buy_signals, sell_signals, buy_price, trigger

def save_csv_file(buy, sell, stock): ################
    ################
    dataset = pd.DataFrame({'BUY': buy, 'SELL': sell,}, columns=[stock,'BUY','SELL'])
    ################
    myfile = dataset.to_csv('C:/Users/shong/Desktop/trade_logs.csv', mode='a', index=False)
    return myfile

def duration(start_hour,start_min,end_hour,end_min):
    time_1 = datetime.timedelta(hours= start_hour, minutes=start_min, seconds=0)
    time_2 = datetime.timedelta(hours= end_hour, minutes=end_min, seconds=0)
    
    time_interval = (time_2 - time_1).total_seconds() + \
                        datetime.timedelta(days=1).total_seconds()
    time_interval = (time_interval/60)/2
    return time_interval

print("functions initialised")
# Out:
# functions initialised

# %%
def main():

    #stock = sys.argv[1] 
    #trade_amount = sys.argv[2]
    
    print("establishing connection...")
    util.startLoop()
    global ib
    ib = IB()
    ib.connect(host='127.0.0.1', port=7497, clientId=1)
    print("connection established")   
    
    stock = 'EAR'
    print("Stocks:", stock)
         
    buy_signals = []
    sell_signals = []
    buy_price = 0
    amount = 300
    minute = 50
    trigger = 0
    
    iterations = int(duration(21, minute, 4, 0)) 
    
    scheduler = sched.scheduler(time.time, time.sleep)

    capture_return = CaptureReturn(get_stock_info, stock)
    
    time_now = time.time()

    while True:
        for count in range(iterations-1):
            scheduler.enterabs(time_now + 120*(count+1), 1, capture_return.call_func)
            data = capture_return.call_func()
            
            if data.empty:
                print("Dataset not found at ", datetime.datetime.now().strftime("%H:%M:%S"))
                continue
            
            buy_signals, sell_signals, buy_price, trigger = trade_algo(data, buy_signals, 
                                                            sell_signals, buy_price, trigger, stock, amount)
            print("This is the current count: ", count)
            scheduler.run()

        if trigger == 1:
            time.sleep(80) ##################
            
            place_order('SELL', stock, amount)
            print("sold :) at market close ", data['Close'][-1])
            
            time.sleep(3) #############
            sell_signals.append(data['Close'][-1])
            time.sleep(3)
            file = save_csv_file(buy_signals, sell_signals, stock)
            time.sleep(3)
            ib.disconnect()
            quit(0)
            time.sleep(3)
            exit()
        else:
            file = save_csv_file(buy_signals, sell_signals, stock)
            time.sleep(3)
            ib.disconnect()
            quit(0)
            time.sleep(3)
            exit()

if __name__ == "__main__":
    main()
# Out:
# establishing connection...
# connection established
# Stocks: EAR
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.953 closing time:  2022-08-17 09:48:00-04:00 time now  21:50:19
# open:  3.039 high:  3.09 low:  2.93 time now:  21:50:19
# This is the current count:  0
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.95 closing time:  2022-08-17 09:50:00-04:00 time now  21:52:19
# open:  2.952 high:  3.03 low:  2.93 time now:  21:52:19
# This is the current count:  1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.875 closing time:  2022-08-17 09:52:00-04:00 time now  21:54:19
# open:  2.949 high:  2.949 low:  2.825 time now:  21:54:19
# This is the current count:  2
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.93 closing time:  2022-08-17 09:54:00-04:00 time now  21:56:19
# open:  2.879 high:  3.0 low:  2.879 time now:  21:56:19
# This is the current count:  3
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.855 closing time:  2022-08-17 09:56:00-04:00 time now  21:58:19
# open:  2.936 high:  2.94 low:  2.83 time now:  21:58:19
# This is the current count:  4
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.92 closing time:  2022-08-17 09:58:00-04:00 time now  22:00:19
# open:  2.852 high:  2.94 low:  2.85 time now:  22:00:19
# This is the current count:  5
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.91 closing time:  2022-08-17 10:00:00-04:00 time now  22:02:19
# open:  2.901 high:  2.97 low:  2.8 time now:  22:02:19
# This is the current count:  6
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.91 closing time:  2022-08-17 10:02:00-04:00 time now  22:04:19
# open:  2.911 high:  2.98 low:  2.83 time now:  22:04:19
# This is the current count:  7
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.875 closing time:  2022-08-17 10:04:00-04:00 time now  22:06:19
# open:  2.91 high:  2.95 low:  2.86 time now:  22:06:19
# This is the current count:  8
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.901 closing time:  2022-08-17 10:06:00-04:00 time now  22:08:19
# open:  2.871 high:  2.95 low:  2.86 time now:  22:08:19
# This is the current count:  9
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.905 closing time:  2022-08-17 10:08:00-04:00 time now  22:10:19
# open:  2.901 high:  3.0 low:  2.89 time now:  22:10:19
# This is the current count:  10
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.905 closing time:  2022-08-17 10:10:00-04:00 time now  22:12:19
# open:  2.91 high:  3.04 low:  2.86 time now:  22:12:19
# This is the current count:  11
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.84 closing time:  2022-08-17 10:12:00-04:00 time now  22:14:19
# open:  2.91 high:  2.91 low:  2.81 time now:  22:14:19
# This is the current count:  12
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.729 closing time:  2022-08-17 10:14:00-04:00 time now  22:16:19
# open:  2.85 high:  2.87 low:  2.68 time now:  22:16:19
# This is the current count:  13
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.69 closing time:  2022-08-17 10:16:00-04:00 time now  22:18:19
# open:  2.72 high:  2.74 low:  2.66 time now:  22:18:19
# This is the current count:  14
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.72 closing time:  2022-08-17 10:18:00-04:00 time now  22:20:19
# open:  2.695 high:  2.74 low:  2.69 time now:  22:20:19
# This is the current count:  15
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.741 closing time:  2022-08-17 10:20:00-04:00 time now  22:22:19
# open:  2.72 high:  2.75 low:  2.68 time now:  22:22:19
# This is the current count:  16
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.714 closing time:  2022-08-17 10:22:00-04:00 time now  22:24:19
# open:  2.746 high:  2.75 low:  2.64 time now:  22:24:19
# This is the current count:  17
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.719 closing time:  2022-08-17 10:24:00-04:00 time now  22:26:19
# open:  2.71 high:  2.73 low:  2.67 time now:  22:26:19
# This is the current count:  18
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.69 closing time:  2022-08-17 10:26:00-04:00 time now  22:28:19
# open:  2.719 high:  2.76 low:  2.68 time now:  22:28:19
# This is the current count:  19
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.59 closing time:  2022-08-17 10:28:00-04:00 time now  22:30:19
# open:  2.69 high:  2.699 low:  2.58 time now:  22:30:19
# This is the current count:  20
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.58 closing time:  2022-08-17 10:30:00-04:00 time now  22:32:19
# open:  2.599 high:  2.61 low:  2.57 time now:  22:32:19
# This is the current count:  21
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# bought at  2.66 at  2022-08-17 10:32:00-04:00 time now:  22:34:19 with engulfing pattern
# open:  2.58 high:  2.66 low:  2.57 body ratios:  4.2105263157894495
# This is the current count:  22
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.601 closing time:  2022-08-17 10:34:00-04:00 time now  22:36:19
# open:  2.66 high:  2.68 low:  2.6 time now:  22:36:19
# This is the current count:  23
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.589 closing time:  2022-08-17 10:36:00-04:00 time now  22:38:19
# open:  2.61 high:  2.62 low:  2.566 time now:  22:38:19
# This is the current count:  24
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.605 closing time:  2022-08-17 10:38:00-04:00 time now  22:40:19
# open:  2.59 high:  2.61 low:  2.55 time now:  22:40:19
# This is the current count:  25
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.66 closing time:  2022-08-17 10:40:00-04:00 time now  22:42:19
# open:  2.6 high:  2.68 low:  2.58 time now:  22:42:19
# This is the current count:  26
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.67 closing time:  2022-08-17 10:42:00-04:00 time now  22:44:19
# open:  2.65 high:  2.68 low:  2.63 time now:  22:44:19
# This is the current count:  27
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.671 closing time:  2022-08-17 10:44:00-04:00 time now  22:46:19
# open:  2.67 high:  2.71 low:  2.65 time now:  22:46:19
# This is the current count:  28
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.708 closing time:  2022-08-17 10:46:00-04:00 time now  22:48:19
# open:  2.67 high:  2.72 low:  2.67 time now:  22:48:19
# This is the current count:  29
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.74 closing time:  2022-08-17 10:48:00-04:00 time now  22:50:19
# open:  2.705 high:  2.75 low:  2.69 time now:  22:50:19
# This is the current count:  30
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.73 closing time:  2022-08-17 10:50:00-04:00 time now  22:52:19
# open:  2.749 high:  2.78 low:  2.66 time now:  22:52:19
# This is the current count:  31
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.69 closing time:  2022-08-17 10:52:00-04:00 time now  22:54:19
# open:  2.725 high:  2.73 low:  2.68 time now:  22:54:19
# This is the current count:  32
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.725 closing time:  2022-08-17 10:54:00-04:00 time now  22:56:19
# open:  2.69 high:  2.729 low:  2.68 time now:  22:56:19
# This is the current count:  33
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.68 closing time:  2022-08-17 10:56:00-04:00 time now  22:58:19
# open:  2.725 high:  2.73 low:  2.66 time now:  22:58:19
# This is the current count:  34
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.675 closing time:  2022-08-17 10:58:00-04:00 time now  23:00:19
# open:  2.689 high:  2.72 low:  2.67 time now:  23:00:19
# This is the current count:  35
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.739 closing time:  2022-08-17 11:00:00-04:00 time now  23:02:19
# open:  2.671 high:  2.75 low:  2.67 time now:  23:02:19
# This is the current count:  36
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.789 closing time:  2022-08-17 11:02:00-04:00 time now  23:04:19
# open:  2.73 high:  2.79 low:  2.721 time now:  23:04:19
# This is the current count:  37
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.86 closing time:  2022-08-17 11:04:00-04:00 time now  23:06:19
# open:  2.787 high:  2.93 low:  2.78 time now:  23:06:19
# This is the current count:  38
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# sold at:  2.97 closing time:  2022-08-17 11:06:00-04:00 time now  23:08:19
# This is the current count:  39
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.31 closing time:  2022-08-17 11:08:00-04:00 time now  23:10:19
# open:  2.971 high:  3.35 low:  2.97 time now:  23:10:19
# This is the current count:  40
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.04 closing time:  2022-08-17 11:10:00-04:00 time now  23:12:19
# open:  3.305 high:  3.35 low:  2.97 time now:  23:12:19
# This is the current count:  41
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.01 closing time:  2022-08-17 11:12:00-04:00 time now  23:14:19
# open:  3.049 high:  3.14 low:  3.01 time now:  23:14:19
# This is the current count:  42
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.04 closing time:  2022-08-17 11:14:00-04:00 time now  23:16:19
# open:  3.02 high:  3.05 low:  2.96 time now:  23:16:19
# This is the current count:  43
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.895 closing time:  2022-08-17 11:16:00-04:00 time now  23:18:19
# open:  3.049 high:  3.05 low:  2.89 time now:  23:18:19
# This is the current count:  44
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.909 closing time:  2022-08-17 11:18:00-04:00 time now  23:20:19
# open:  2.892 high:  2.93 low:  2.88 time now:  23:20:19
# This is the current count:  45
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.881 closing time:  2022-08-17 11:20:00-04:00 time now  23:22:19
# open:  2.91 high:  2.91 low:  2.85 time now:  23:22:19
# This is the current count:  46
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.9 closing time:  2022-08-17 11:22:00-04:00 time now  23:24:19
# open:  2.89 high:  2.91 low:  2.88 time now:  23:24:19
# This is the current count:  47
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.98 closing time:  2022-08-17 11:24:00-04:00 time now  23:26:19
# open:  2.898 high:  2.98 low:  2.87 time now:  23:26:19
# This is the current count:  48
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.03 closing time:  2022-08-17 11:26:00-04:00 time now  23:28:19
# open:  2.98 high:  3.1 low:  2.94 time now:  23:28:19
# This is the current count:  49
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# bought at  3.029 at  2022-08-17 11:28:00-04:00 time now:  23:30:19 with hammer pattern
# open:  3.024 high:  3.04 low:  2.97 low stick/body:  10.800000000000196 high stick/low stick 0.2037037037037066
# This is the current count:  50
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.08 closing time:  2022-08-17 11:30:00-04:00 time now  23:32:19
# open:  3.021 high:  3.13 low:  3.011 time now:  23:32:19
# This is the current count:  51
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.15 closing time:  2022-08-17 11:32:00-04:00 time now  23:34:19
# open:  3.07 high:  3.18 low:  3.07 time now:  23:34:19
# This is the current count:  52
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.085 closing time:  2022-08-17 11:34:00-04:00 time now  23:36:19
# open:  3.15 high:  3.15 low:  3.07 time now:  23:36:19
# This is the current count:  53
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  2.995 closing time:  2022-08-17 11:36:00-04:00 time now  23:38:19
# open:  3.08 high:  3.09 low:  2.97 time now:  23:38:19
# This is the current count:  54
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.045 closing time:  2022-08-17 11:38:00-04:00 time now  23:40:19
# open:  3.0 high:  3.049 low:  2.98 time now:  23:40:19
# This is the current count:  55
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.14 closing time:  2022-08-17 11:40:00-04:00 time now  23:42:19
# open:  3.049 high:  3.17 low:  3.02 time now:  23:42:19
# This is the current count:  56
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.139 closing time:  2022-08-17 11:42:00-04:00 time now  23:44:19
# open:  3.141 high:  3.18 low:  3.11 time now:  23:44:19
# This is the current count:  57
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.145 closing time:  2022-08-17 11:44:00-04:00 time now  23:46:19
# open:  3.13 high:  3.17 low:  3.07 time now:  23:46:19
# This is the current count:  58
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.1 closing time:  2022-08-17 11:46:00-04:00 time now  23:48:19
# open:  3.15 high:  3.17 low:  3.06 time now:  23:48:19
# This is the current count:  59
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.24 closing time:  2022-08-17 11:48:00-04:00 time now  23:50:19
# open:  3.098 high:  3.25 low:  3.05 time now:  23:50:19
# This is the current count:  60
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.24 closing time:  2022-08-17 11:50:00-04:00 time now  23:52:19
# open:  3.235 high:  3.328 low:  3.16 time now:  23:52:19
# This is the current count:  61
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.3 closing time:  2022-08-17 11:52:00-04:00 time now  23:54:19
# open:  3.24 high:  3.32 low:  3.2 time now:  23:54:19
# This is the current count:  62
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.25 closing time:  2022-08-17 11:54:00-04:00 time now  23:56:19
# open:  3.319 high:  3.33 low:  3.19 time now:  23:56:19
# This is the current count:  63
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.11 closing time:  2022-08-17 11:56:00-04:00 time now  23:58:19
# open:  3.25 high:  3.26 low:  3.07 time now:  23:58:19
# This is the current count:  64
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.075 closing time:  2022-08-17 11:58:00-04:00 time now  00:00:19
# open:  3.109 high:  3.15 low:  3.02 time now:  00:00:19
# This is the current count:  65
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.12 closing time:  2022-08-17 12:00:00-04:00 time now  00:02:19
# open:  3.079 high:  3.2 low:  3.06 time now:  00:02:19
# This is the current count:  66
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.115 closing time:  2022-08-17 12:02:00-04:00 time now  00:04:19
# open:  3.12 high:  3.2 low:  3.09 time now:  00:04:19
# This is the current count:  67
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.12 closing time:  2022-08-17 12:04:00-04:00 time now  00:06:19
# open:  3.119 high:  3.15 low:  3.09 time now:  00:06:19
# This is the current count:  68
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.12 closing time:  2022-08-17 12:06:00-04:00 time now  00:08:19
# open:  3.12 high:  3.16 low:  3.1 time now:  00:08:19
# This is the current count:  69
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.11 closing time:  2022-08-17 12:08:00-04:00 time now  00:10:19
# open:  3.13 high:  3.15 low:  3.07 time now:  00:10:19
# This is the current count:  70
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.14 closing time:  2022-08-17 12:10:00-04:00 time now  00:12:19
# open:  3.11 high:  3.15 low:  3.09 time now:  00:12:19
# This is the current count:  71
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.155 closing time:  2022-08-17 12:12:00-04:00 time now  00:14:19
# open:  3.14 high:  3.17 low:  3.11 time now:  00:14:19
# This is the current count:  72
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.119 closing time:  2022-08-17 12:14:00-04:00 time now  00:16:19
# open:  3.16 high:  3.21 low:  3.1 time now:  00:16:19
# This is the current count:  73
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.115 closing time:  2022-08-17 12:16:00-04:00 time now  00:18:19
# open:  3.12 high:  3.14 low:  3.08 time now:  00:18:19
# This is the current count:  74
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.15 closing time:  2022-08-17 12:18:00-04:00 time now  00:20:19
# open:  3.115 high:  3.17 low:  3.1 time now:  00:20:19
# This is the current count:  75
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.15 closing time:  2022-08-17 12:20:00-04:00 time now  00:22:19
# open:  3.14 high:  3.17 low:  3.13 time now:  00:22:19
# This is the current count:  76
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.208 closing time:  2022-08-17 12:22:00-04:00 time now  00:24:19
# open:  3.15 high:  3.23 low:  3.15 time now:  00:24:19
# This is the current count:  77
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.175 closing time:  2022-08-17 12:24:00-04:00 time now  00:26:19
# open:  3.2 high:  3.21 low:  3.09 time now:  00:26:19
# This is the current count:  78
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.19 closing time:  2022-08-17 12:26:00-04:00 time now  00:28:19
# open:  3.151 high:  3.25 low:  3.14 time now:  00:28:19
# This is the current count:  79
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.23 closing time:  2022-08-17 12:28:00-04:00 time now  00:30:19
# open:  3.199 high:  3.24 low:  3.17 time now:  00:30:19
# This is the current count:  80
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.28 closing time:  2022-08-17 12:30:00-04:00 time now  00:32:19
# open:  3.23 high:  3.285 low:  3.2 time now:  00:32:19
# This is the current count:  81
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# sold at:  3.39 closing time:  2022-08-17 12:32:00-04:00 time now  00:34:19
# This is the current count:  82
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.265 closing time:  2022-08-17 12:34:00-04:00 time now  00:36:19
# open:  3.39 high:  3.41 low:  3.18 time now:  00:36:19
# This is the current count:  83
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.28 closing time:  2022-08-17 12:36:00-04:00 time now  00:38:19
# open:  3.269 high:  3.29 low:  3.23 time now:  00:38:19
# This is the current count:  84
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.265 closing time:  2022-08-17 12:38:00-04:00 time now  00:40:19
# open:  3.289 high:  3.29 low:  3.24 time now:  00:40:19
# This is the current count:  85
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.255 closing time:  2022-08-17 12:40:00-04:00 time now  00:42:19
# open:  3.27 high:  3.29 low:  3.22 time now:  00:42:19
# This is the current count:  86
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.18 closing time:  2022-08-17 12:42:00-04:00 time now  00:44:19
# open:  3.25 high:  3.25 low:  3.16 time now:  00:44:19
# This is the current count:  87
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.129 closing time:  2022-08-17 12:44:00-04:00 time now  00:46:19
# open:  3.18 high:  3.2 low:  3.09 time now:  00:46:19
# This is the current count:  88
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.129 closing time:  2022-08-17 12:46:00-04:00 time now  00:48:19
# open:  3.129 high:  3.14 low:  3.1 time now:  00:48:19
# This is the current count:  89
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.055 closing time:  2022-08-17 12:48:00-04:00 time now  00:50:19
# open:  3.13 high:  3.16 low:  3.0 time now:  00:50:19
# This is the current count:  90
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.068 closing time:  2022-08-17 12:50:00-04:00 time now  00:52:19
# open:  3.055 high:  3.07 low:  3.03 time now:  00:52:19
# This is the current count:  91
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.064 closing time:  2022-08-17 12:52:00-04:00 time now  00:54:19
# open:  3.061 high:  3.07 low:  3.04 time now:  00:54:19
# This is the current count:  92
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.07 closing time:  2022-08-17 12:54:00-04:00 time now  00:56:19
# open:  3.069 high:  3.08 low:  3.03 time now:  00:56:19
# This is the current count:  93
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.05 closing time:  2022-08-17 12:56:00-04:00 time now  00:58:19
# open:  3.064 high:  3.07 low:  3.03 time now:  00:58:19
# This is the current count:  94
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.009 closing time:  2022-08-17 12:58:00-04:00 time now  01:00:19
# open:  3.05 high:  3.06 low:  3.0 time now:  01:00:19
# This is the current count:  95
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.119 closing time:  2022-08-17 13:00:00-04:00 time now  01:02:19
# open:  3.01 high:  3.15 low:  3.0 time now:  01:02:19
# This is the current count:  96
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.15 closing time:  2022-08-17 13:02:00-04:00 time now  01:04:19
# open:  3.118 high:  3.16 low:  3.09 time now:  01:04:19
# This is the current count:  97
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.129 closing time:  2022-08-17 13:04:00-04:00 time now  01:06:19
# open:  3.149 high:  3.15 low:  3.1 time now:  01:06:19
# This is the current count:  98
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.076 closing time:  2022-08-17 13:06:00-04:00 time now  01:08:19
# open:  3.13 high:  3.14 low:  3.04 time now:  01:08:19
# This is the current count:  99
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.09 closing time:  2022-08-17 13:08:00-04:00 time now  01:10:19
# open:  3.071 high:  3.1 low:  3.07 time now:  01:10:19
# This is the current count:  100
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# [*********************100%***********************]  1 of 1 completed
# Downloaded in Attempt 1
# closing price:  3.139 closing time:  2022-08-17 13:10:00-04:00 time now  01:12:19
# open:  3.095 high:  3.14 low:  3.09 time now:  01:12:19
# This is the current count:  101
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:14:59
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:15:21
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:15:30
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:15:39
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:15:48
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:15:58
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:16:07
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:16:16
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:16:25
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:16:34
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:16:43
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:16:52
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:17:01
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:17:44
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:18:00
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:18:31
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:18:59
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:19:09
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:19:18
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# ...
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:30:44
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:31:12
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:31:32
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:31:53
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:32:04
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:32:24
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:32:52
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:33:12
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:33:33
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:33:50
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:34:07
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:34:18
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:34:38
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:34:52
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:35:09
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:35:41
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:36:01
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:36:29
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:36:38
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:36:47
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:37:18
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:37:39
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:37:59
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:38:16
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:38:47
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:39:04
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 1 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 2 Failed, Dataset Empty.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EAR: No data found for this date range, symbol may be delisted
# Attempt 3 Failed, Dataset Empty.
# Dataset not found at  01:39:25
# 2022-08-18 01:39:31.137122 Now the system will exit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
